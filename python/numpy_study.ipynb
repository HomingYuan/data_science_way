# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DataAnalyst.csv', delimiter=',',header=None,encoding="gb2312")  # encoding = 'gb2312' 读取中文

# %%
data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>10</th>
#       <th>11</th>
#       <th>12</th>
#       <th>13</th>
#       <th>14</th>
#       <th>15</th>
#       <th>16</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>city</td>
#       <td>companyFullName</td>
#       <td>companyId</td>
#       <td>companyLabelList</td>
#       <td>companyShortName</td>
#       <td>companySize</td>
#       <td>businessZones</td>
#       <td>firstType</td>
#       <td>secondType</td>
#       <td>education</td>
#       <td>industryField</td>
#       <td>positionId</td>
#       <td>positionAdvantage</td>
#       <td>positionName</td>
#       <td>positionLables</td>
#       <td>salary</td>
# ...

# %%
import tushare as ts

# %%
stock_data = ts.get_hist_data('600848')

# %%
stock_data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>open</th>
#       <th>high</th>
#       <th>close</th>
#       <th>low</th>
#       <th>volume</th>
#       <th>price_change</th>
#       <th>p_change</th>
#       <th>ma5</th>
#       <th>ma10</th>
#       <th>ma20</th>
#       <th>v_ma5</th>
#       <th>v_ma10</th>
#       <th>v_ma20</th>
#     </tr>
#     <tr>
#       <th>date</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2017-05-10</th>
#       <td>18.63</td>
#       <td>18.80</td>
#       <td>18.32</td>
#       <td>18.27</td>
#       <td>19551.74</td>
#       <td>-0.40</td>
#       <td>-2.14</td>
#       <td>18.662</td>
#       <td>18.903</td>
# ...

# %%
stock_data.to_csv('stock_data.csv') # 写入数据

# %%
data_stock = pd.read_csv('stock_data.csv')

# %%
stock_date = data_stock['date']

# %%
stock_date
# Out:
# 0      2017-05-10
# 1      2017-05-09
# 2      2017-05-08
# 3      2017-05-05
# 4      2017-05-04
# 5      2017-05-03
# 6      2017-05-02
# 7      2017-04-28
# 8      2017-04-27
# 9      2017-04-26
# 10     2017-04-25
# 11     2017-04-24
# 12     2017-04-21
# 13     2017-04-20
# 14     2017-04-19
# 15     2017-04-18
# 16     2017-04-17
# 17     2017-04-14
# 18     2017-04-13
# 19     2017-04-12
# 20     2017-04-11
# 21     2017-04-10
# 22     2017-04-07
# 23     2017-04-06
# 24     2017-04-05
# 25     2017-03-31
# 26     2017-03-30
# 27     2017-03-29
# 28     2017-03-28
# 29     2017-03-27
#           ...
# 470    2015-01-20
# 471    2015-01-19
# 472    2015-01-16
# 473    2015-01-15
# 474    2015-01-14
# 475    2015-01-13
# 476    2015-01-12
# 477    2015-01-09
# 478    2015-01-08
# 479    2015-01-07
# 480    2015-01-06
# 481    2015-01-05
# 482    2014-12-31
# 483    2014-12-30
# 484    2014-12-29
# 485    2014-12-26
# 486    2014-12-25
# 487    2014-12-24
# 488    2014-12-23
# ...
