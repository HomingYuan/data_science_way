# %%
import  matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
import numpy as np

# %%
img = mpimg.imread('stinkbug.png')

# %%
img
# Out:
# array([[[ 0.40784314,  0.40784314,  0.40784314],
#         [ 0.40784314,  0.40784314,  0.40784314],
#         [ 0.40784314,  0.40784314,  0.40784314],
#         ...,
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098]],
#
#        [[ 0.41176471,  0.41176471,  0.41176471],
#         [ 0.41176471,  0.41176471,  0.41176471],
#         [ 0.41176471,  0.41176471,  0.41176471],
#         ...,
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098],
#         [ 0.42745098,  0.42745098,  0.42745098]],
#
#        [[ 0.41960785,  0.41960785,  0.41960785],
#         [ 0.41568628,  0.41568628,  0.41568628],
#         [ 0.41568628,  0.41568628,  0.41568628],
#         ...,
#         [ 0.43137255,  0.43137255,  0.43137255],
#         [ 0.43137255,  0.43137255,  0.43137255],
#         [ 0.43137255,  0.43137255,  0.43137255]],
#
#        ...,
#        [[ 0.43921569,  0.43921569,  0.43921569],
#         [ 0.43529412,  0.43529412,  0.43529412],
#         [ 0.43137255,  0.43137255,  0.43137255],
#         ...,
#         [ 0.45490196,  0.45490196,  0.45490196],
#         [ 0.4509804 ,  0.4509804 ,  0.4509804 ],
#         [ 0.4509804 ,  0.4509804 ,  0.4509804 ]],
#
#        [[ 0.44313726,  0.44313726,  0.44313726],
#         [ 0.44313726,  0.44313726,  0.44313726],
#         [ 0.43921569,  0.43921569,  0.43921569],
#         ...,
#         [ 0.4509804 ,  0.4509804 ,  0.4509804 ],
#         [ 0.44705883,  0.44705883,  0.44705883],
#         [ 0.44705883,  0.44705883,  0.44705883]],
#
#        [[ 0.44313726,  0.44313726,  0.44313726],
#         [ 0.4509804 ,  0.4509804 ,  0.4509804 ],
#         [ 0.4509804 ,  0.4509804 ,  0.4509804 ],
#         ...,
#         [ 0.44705883,  0.44705883,  0.44705883],
#         [ 0.44705883,  0.44705883,  0.44705883],
#         [ 0.44313726,  0.44313726,  0.44313726]]], dtype=float32)

# %%
imgplot = plt.imshow(img)

# %%
imgplot

# %%
plt.show()

# %%
lum_img = img[:,:,0]

# %%
imgplot = plt.imshow(lum_img)

# %%
plt.show()

# %%
imgplot.set_cmap('hot')

# %%
imgplot.set_cmap('spectral')
# Out:
# D:\python3.4\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The spectral and spectral_r colormap was deprecated in version 2.0. Use nipy_spectral and nipy_spectral_r instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.colorbar()

# %%
plt.savefig('bug.png')

# %%
import image

# %%
img = image.open('strinkbug.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-16b891f1a7bb> in <module>()
# ----> 1 img = image.open('strinkbug.png')
#
# AttributeError: module 'image' has no attribute 'open'

# %%
import PIL
